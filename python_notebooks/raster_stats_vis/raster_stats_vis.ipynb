# %%
import pandas as pd 
import numpy as np

# %%
replanted = pd.read_csv('../../output/disturbances_planted.csv')
harvest = pd.read_csv('../../output/harvest_not_planted.csv')
fire = pd.read_csv('../../output/fire_not_planted.csv')

# %%
bc = pd.read_csv('../../output/bc_avg.csv')

# %%
import datetime


df[(df['ID'] == 3688575) & ((str(datetime.date(2010, 1, 1)) < df['date']) & (df['date'] < str(datetime.date(2025, 1, 1))))][['MeanValue', 'date']].plot(x='date', y='MeanValue')
# Out:
# <Axes: xlabel='date'>

# %%
harvest_filtered = harvest.dropna()

# %%
replanted_filtered = replanted.dropna()

# %%
fire_filtered = fire.dropna()

# %%
bc['date'] = pd.to_datetime(bc['date'])
harvest_filtered['date'] = pd.to_datetime(harvest_filtered['date'])
fire_filtered['date'] = pd.to_datetime(fire_filtered['date'])
replanted_filtered['date'] = pd.to_datetime(replanted_filtered['date'])
# Out:
# C:\Users\jbjos\AppData\Local\Temp\ipykernel_10908\1312334280.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   harvest_filtered['date'] = pd.to_datetime(harvest_filtered['date'])
# C:\Users\jbjos\AppData\Local\Temp\ipykernel_10908\1312334280.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fire_filtered['date'] = pd.to_datetime(fire_filtered['date'])
# C:\Users\jbjos\AppData\Local\Temp\ipykernel_10908\1312334280.py:4: SettingWithCopyWarning:
# ...

# %%
bc.groupby('date').sum()['MeanValue'].plot()
harvest_filtered.groupby('date').mean()['MedianValue'].plot()
replanted_filtered.drop(0).groupby('date').mean()['MedianValue'].plot()
fire_filtered.groupby('date').mean()['MedianValue'].plot()
# Out:
# <Axes: xlabel='date'>
