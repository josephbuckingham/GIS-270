# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../../output/disturbances_planted.csv')

# %%
df
# Out:
#          Unnamed: 0       ID  MinValue  MaxValue  MeanValue  MedianValue  \
# 0                 0        0  0.000000  1.000000   0.499189     0.508946
# 1                 1   538478  0.391779  0.756124   0.560025     0.532173
# 2                 2  1610936       NaN       NaN        NaN          NaN
# 3                 3  1610938       NaN       NaN        NaN          NaN
# 4                 4  1610939       NaN       NaN        NaN          NaN
# ...             ...      ...       ...       ...        ...          ...
# 8986786       14328  4123725       NaN       NaN        NaN          NaN
# 8986787       14329  4123743       NaN       NaN        NaN          NaN
# 8986788       14330  4123746       NaN       NaN        NaN          NaN
# 8986789       14331  4123749       NaN       NaN        NaN          NaN
# 8986790       14332  4123753       NaN       NaN        NaN          NaN
#
#          StdevValue  CountValue        date
# 0          0.183635    823638.0  2003-03-17
# ...

# %%
import datetime


df[(df['ID'] == 3688575) & ((str(datetime.date(2016, 1, 1)) < df['date']) & (df['date'] < str(datetime.date(2024, 1, 1))))][['MeanValue', 'date']].plot(x='date', y='MeanValue')
# Out:
# <Axes: xlabel='date'>
