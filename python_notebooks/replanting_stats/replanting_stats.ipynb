# %%
import geopandas as gpd
import geoplot as gplt
import geoplot.crs as gcrs

# %%
planted = gpd.read_file('../../processing/disturbances_planted/disturbances_planted.gdb')
planted
# Out:
#        ACTIVITY_TREATMENT_UNIT_ID ACTIVITY_LICENSEE_ID  OPENING_ID  \
# 0                         1811859  Brave Holdings Ltd.     1074311
# 1                         1869960                 None     1090429
# 2                         2095580                 None       79890
# 3                         1881476                 None  -586630000
# 4                         1634777                 None      103086
# ...                           ...                  ...         ...
# 15562                     4123456           1005149998       83740
# 15563                     4123743           1005156369     1768453
# 15564                     4123663           1005103572     1718437
# 15565                     4123661           1004800807     1765734
# 15566                     4123657           1005150054     1776192
#
#              MAP_LABEL SILV_BASE_CODE SILV_TECHNIQUE_CODE SILV_METHOD_CODE  \
# 0         SX 690(2006)             PL                  PL            CTAIN
# ...

# %%
original_planted = gpd.read_file('../../input/RSLT_PLANTING.gdb')
# Out:
# 21585

# %%
(original_planted.geometry.area.sum() - planted.geometry.area.sum())/original_planted.geometry.area.sum()
# Out:
# np.float64(0.8109237861644224)
